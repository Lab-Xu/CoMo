# %% [markdown]
# ## initial setting

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# ## package Importing

# %%
import copy
import scanpy as sc
import numpy as np
import time
import tool.file_tool as ft
import os
import matplotlib.pyplot as plt
import pandas as pd
import itertools
import main
from CoMo.preprocess import clr_normalize_each_cell, pca, lsi
import matplotlib.pyplot as plt
from CoMo.preprocess import fix_seed

# %% [markdown]
# ## parameter setting

# %%
dataset_name = 'Human_Tonsil'
RNA_data_type = '10x'
omics_type2 = 'Protein'
clusters_num = 10

stage_weights = {
                'recon': [1.0, 5.0, 0.0, 0.0, 0.0],  # Stage 1: reconstruction
                'contrast': [1.0, 5.0, 1, 5.0, 0.0],  # Stage 2: reduce recon and cluster, increase contrast
            }
stage_epochs = {'recon': 200, 'contrast': 400}

# %%
seed = 2025

# %%
fix_seed(seed=seed)

# %% [markdown]
# ## data reading

# %%
# read data
file_fold = f'../data/{dataset_name}/h5ad/'
adata_omics1 = sc.read_h5ad(file_fold + 'adata_rna.h5ad')
adata_omics2 = sc.read_h5ad(file_fold + 'adata_protein.h5ad')
adata_omics1.var_names_make_unique()
adata_omics2.var_names_make_unique()
adata_omics1.obsm['spatial'][:, 1] = -adata_omics1.obsm['spatial'][:, 1]
adata_omics2.obsm['spatial'][:, 1] = -adata_omics1.obsm['spatial'][:, 1]

# preprocess
# transcriptome & Protein
n_comps = 1000 # or adata_omics2.n_vars
sc.pp.filter_genes(adata_omics1, min_cells=10)
sc.pp.highly_variable_genes(adata_omics1, flavor="seurat_v3", n_top_genes=3000)
sc.pp.normalize_total(adata_omics1, target_sum=1e4)
sc.pp.log1p(adata_omics1)
sc.pp.scale(adata_omics1)
adata_omics1_high =  adata_omics1[:, adata_omics1.var['highly_variable']]
adata_omics1.obsm['feat'] = pca(adata_omics1_high, n_comps=n_comps-1)


adata_omics2 = clr_normalize_each_cell(adata_omics2)
sc.pp.scale(adata_omics2)
adata_omics2.obsm['feat'] = pca(adata_omics2, n_comps=n_comps-1)

omics_list = [adata_omics1, adata_omics2]

# transcriptome & epigenome
# sc.pp.filter_genes(adata_omics1, min_cells=10)
# sc.pp.filter_cells(adata_omics1, min_genes=200)
# sc.pp.highly_variable_genes(adata_omics1, flavor="seurat_v3", n_top_genes=3000)
# sc.pp.normalize_total(adata_omics1, target_sum=1e4)
# sc.pp.log1p(adata_omics1)
# sc.pp.scale(adata_omics1)
# adata_omics1_high =  adata_omics1[:, adata_omics1.var['highly_variable']]
# adata_omics1.obsm['feat'] = pca(adata_omics1_high, n_comps=n_comps)

# adata_omics2 = adata_omics2[adata_omics1.obs_names].copy()
# if 'X_lsi' not in adata_omics2.obsm.keys():
#     sc.pp.highly_variable_genes(adata_omics2, flavor="seurat_v3", n_top_genes=3000)
#     lsi(adata_omics2, use_highly_variable=False, n_components=n_comps+1)

# adata_omics2.obsm['feat'] = adata_omics2.obsm['X_lsi'].copy()

# %% [markdown]
# ## multi-omics integration & spatial domain identification

# %%
adata, refine_exter, refine_inter = main.run_algorithms(omics_list, 
                                                            RNA_data_type=RNA_data_type,
                                                            have_anno=False,
                                                            n_clusters=clusters_num,
                                                            step_by_step_train=True,
                                                            stage_weights=stage_weights,
                                                            stage_epochs=stage_epochs,
                                                            random_seed=seed)
# Out:
# ========seed:2025========
# self.adj_spatial_omics1 len: 4194
# step by step train model
#   1%|█                                                                                 | 8/600 [00:00<00:50, 11.73it/s]
# current_stage: recon
# weights: [1.0, 5.0, 0.0, 0.0, 0.0]
#  18%|██████████████▍                                                                 | 108/600 [00:02<00:07, 69.70it/s]
# current_stage: recon
# weights: [1.0, 5.0, 0.0, 0.0, 0.0]
#  35%|████████████████████████████▏                                                   | 211/600 [00:03<00:05, 70.06it/s]
# current_stage: contrast
# weights: [1.0, 5.0, 1, 5.0, 0.0]
#  51%|████████████████████████████████████████▉                                       | 307/600 [00:05<00:04, 69.12it/s]
# current_stage: contrast
# weights: [1.0, 5.0, 1, 5.0, 0.0]
#  68%|██████████████████████████████████████████████████████▌                         | 409/600 [00:06<00:02, 70.91it/s]
# current_stage: contrast
# weights: [1.0, 5.0, 1, 5.0, 0.0]
#  86%|████████████████████████████████████████████████████████████████████▍           | 513/600 [00:08<00:01, 70.46it/s]
# current_stage: contrast
# weights: [1.0, 5.0, 1, 5.0, 0.0]
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.44it/s]
# Model training finished!
# R[write to console]:     __  ___________    __  _____________
#    /  |/  / ____/ /   / / / / ___/_  __/
#   / /|_/ / /   / /   / / / /\__ \ / /
#  / /  / / /___/ /___/ /_/ /___/ // /
# /_/  /_/\____/_____/\____//____//_/    version 5.4.9
# Type 'citation("mclust")' for citing this R package in publications.
# fitting ...
#   |======================================================================| 100%
# ========internal metrics========
# moran index:0.4981, p-value: 0.001

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4194 × 18030
#     obs: 'in_tissue', 'array_row', 'array_col', 'mclust', 'refine_CoMo'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'spatial', 'hvg', 'log1p', 'adj_spatial', 'adj_contrast'
#     obsm: 'spatial', 'feat', 'adj_feature', 'emb_latent_omics1', 'emb_latent_omics2', 'CoMo', 'CoMo_pca'

# %% [markdown]
# ## visualization

# %%
plt.rcParams["figure.figsize"] = (4, 4)
fig = sc.pl.embedding(adata, basis="spatial", color='refine_CoMo', title='CoMo', 
                     legend_loc=None,show=False, s=50, return_fig=True);
plt.tight_layout(w_pad=0.3)
for ax in fig.axes:
    ax.set_xlabel("")
    ax.set_ylabel("")
plt.show()
# Out:
# Text(0.5, 38.444444444444436, '')
# Text(44.44444444444444, 0.5, '')
